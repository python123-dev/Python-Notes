# %%
import pandas as pd
import numpy as np

# %%
#pandas series- is a table column- 1d array
my_series=[1,3,6,9]
my_var=pd.Series(my_series)
my_var
# Out:
# 0    1
# 1    3
# 2    6
# 3    9
# dtype: int64

# %%
my_var[2]
# Out:
# 6

# %%
#lable using index argument
my_index=['a','b','c','d']
my_var2=pd.Series(my_series,index=my_index)
my_var2
# Out:
# a    1
# b    3
# c    6
# d    9
# dtype: int64

# %%
my_var2['c']
# Out:
# 6

# %%
cars={'tesla':3,'bmw':2,'suv':6}
my_var3=pd.Series(cars)
print(my_var3)
# Out:
# tesla    3
# bmw      2
# suv      6
# dtype: int64

# %%
my_var3['suv']
# Out:
# 6

# %%
#dataframe
from numpy.random import randn

# %%
my_data=randn(4,3) #rows and columns
my_rows=['A','B','C','D']
my_cols=['Monday','Tuesday','Wednesday']

# %%
#create dataframe
my_df=pd.DataFrame(my_data,my_rows,my_cols)
my_df
# Out:
#      Monday   Tuesday  Wednesday
# A -1.459912 -0.244165   0.118351
# B  0.279121 -0.490950  -0.399506
# C  1.303328 -0.578568   1.074107
# D  0.215084  0.909229   0.612713

# %%
#import csv

my_df2=pd.read_csv('dog_data.csv')
my_df2
# Out:
#                     Breed              Color        DogName  OwnerZip
# 0                COCKAPOO              BROWN        CHARLEY     15236
# 1            GER SHEPHERD        BLACK/BROWN         TACODA     15238
# 2           BELG MALINOIS            BRINDLE           EICH     15238
# 3                   MIXED        BLACK/BROWN          ARROW     15104
# 4     AM PIT BULL TERRIER        WHITE/BROWN         OAKLEY     15139
# ...                   ...                ...            ...       ...
# 2665         GOLDENDOODLE              BROWN        WINSLOW     15044
# 2666    YORKSHIRE TERRIER        BLACK/BROWN  ROCKY KALAKOS     15220
# 2667              LAB MIX  WHITE/BLACK/BROWN          ELLIE     15220
# 2668         GOLDENDOODLE              WHITE       CLARENCE     15143
# 2669    SHETLAND SHEEPDOG              BLACK        GRIFFIN     15136
#
# [2670 rows x 4 columns]

# %%
#pull out rows
my_df2.loc[17]
# Out:
# Breed       COCKER SPANIEL
# Color               BLONDE
# DogName             JUILET
# OwnerZip             15214
# Name: 17, dtype: object

# %%
#multirows
my_df2.loc[[0,5,8]]
# Out:
#                Breed        Color     DogName  OwnerZip
# 0           COCKAPOO        BROWN     CHARLEY     15236
# 5   SCOTTISH TERRIER        BLACK      BAILEY     15129
# 8  SHETLAND SHEEPDOG  WHITE/BROWN  ZOE VITSAS     15238

# %%
#grab first 5 rows(or)you can also pass nay number to the head function
my_df2.head()
# Out:
#                  Breed        Color  DogName  OwnerZip
# 0             COCKAPOO        BROWN  CHARLEY     15236
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238
# 2        BELG MALINOIS      BRINDLE     EICH     15238
# 3                MIXED  BLACK/BROWN    ARROW     15104
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139

# %%
#last 5 rows
my_df2.tail()
# Out:
#                   Breed              Color        DogName  OwnerZip
# 2665       GOLDENDOODLE              BROWN        WINSLOW     15044
# 2666  YORKSHIRE TERRIER        BLACK/BROWN  ROCKY KALAKOS     15220
# 2667            LAB MIX  WHITE/BLACK/BROWN          ELLIE     15220
# 2668       GOLDENDOODLE              WHITE       CLARENCE     15143
# 2669  SHETLAND SHEEPDOG              BLACK        GRIFFIN     15136

# %%
#info about the dataframe
my_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2670 entries, 0 to 2669
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Breed     2670 non-null   object
#  1   Color     2665 non-null   object
#  2   DogName   2669 non-null   object
#  3   OwnerZip  2670 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 83.6+ KB

# %%
#shape of rows and columns
my_df2.shape
# Out:
# (2670, 4)

# %%
# number of dimensions
my_df2.ndim
# Out:
# 2

# %%
#Get column datatypes
my_df2.dtypes
# Out:
# Breed       object
# Color       object
# DogName     object
# OwnerZip     int64
# dtype: object

# %%
# Get some satistics about the data
my_df2.describe()
# Out:
#            OwnerZip
# count   2670.000000
# mean   15268.109738
# std     2747.560641
# min    15003.000000
# 25%    15102.000000
# 50%    15136.000000
# 75%    15227.000000
# max    97206.000000

# %%
# Describe on specific column
my_df2['Breed'].describe()
# Out:
# count      2670
# unique      185
# top       MIXED
# freq        235
# Name: Breed, dtype: object

# %%
# Describe on specific column
my_df2['Color'].describe()
# Out:
# count      2665
# unique       72
# top       BLACK
# freq        371
# Name: Color, dtype: object

# %%
# Describe on specific column
my_df2['DogName'].describe()
# Out:
# count     2669
# unique    1428
# top       LUCY
# freq        35
# Name: DogName, dtype: object

# %%
#Select specific Column using brackets
my_df2['DogName']
# Out:
# 0             CHARLEY
# 1              TACODA
# 2                EICH
# 3               ARROW
# 4              OAKLEY
#             ...
# 2665          WINSLOW
# 2666    ROCKY KALAKOS
# 2667            ELLIE
# 2668         CLARENCE
# 2669          GRIFFIN
# Name: DogName, Length: 2670, dtype: object

# %%
# Select specific Column using dot notation
my_df2.DogName
# Out:
# 0             CHARLEY
# 1              TACODA
# 2                EICH
# 3               ARROW
# 4              OAKLEY
#             ...
# 2665          WINSLOW
# 2666    ROCKY KALAKOS
# 2667            ELLIE
# 2668         CLARENCE
# 2669          GRIFFIN
# Name: DogName, Length: 2670, dtype: object

# %%
#Select specific Column using Location
my_df2.iloc[:19,2]
# Out:
# 0               CHARLEY
# 1                TACODA
# 2                  EICH
# 3                 ARROW
# 4                OAKLEY
# 5                BAILEY
# 6     MIMI PEARL FOSTER
# 7                 LEROI
# 8            ZOE VITSAS
# 9                 TAFFY
# 10                 DUDE
# 11              CHICKIE
# 12                 KING
# 13                EMILY
# 14                ELLIE
# 15                RUSTY
# 16                  NaN
# 17               JUILET
# 18                ROMEO
# Name: DogName, dtype: object

# %%
#count Distinct values- descending
my_df2['Color'].value_counts()
# Out:
# BLACK                   371
# BROWN                   309
# WHITE                   226
# WHITE/BLACK             196
# BLACK/BROWN             183
#                        ...
# BLACK/ORANGE/BRINDLE      1
# BROWN/ORANGE              1
# BROWN/FAWN                1
# BLACK/BROWN/GREY          1
# BROWN/LIVER               1
# Name: Color, Length: 72, dtype: int64

# %%
#count Distinct values- Ascending
my_df2['Color'].value_counts(ascending=True)
# Out:
# BROWN/LIVER               1
# BROWN/FAWN                1
# BROWN/ORANGE              1
# BLACK/ORANGE/BRINDLE      1
# BLACK/BROWN/GREY          1
#                        ...
# BLACK/BROWN             183
# WHITE/BLACK             196
# WHITE                   226
# BROWN                   309
# BLACK                   371
# Name: Color, Length: 72, dtype: int64

# %%
# get relative frequency -percentage
my_df2['Color'].value_counts(normalize=True) #*100
# Out:
# BLACK                   0.139212
# BROWN                   0.115947
# WHITE                   0.084803
# WHITE/BLACK             0.073546
# BLACK/BROWN             0.068668
#                           ...
# BLACK/ORANGE/BRINDLE    0.000375
# BROWN/ORANGE            0.000375
# BROWN/FAWN              0.000375
# BLACK/BROWN/GREY        0.000375
# BROWN/LIVER             0.000375
# Name: Color, Length: 72, dtype: float64

# %%
# Specific item count
my_df2['Color'].value_counts()['WHITE']
# Out:
# 226

# %%
#Count unique values- Size (groupby().size)

my_df2.groupby('Color').size()
# Out:
# Color
# APRICOT              15
# BEIGE                 5
# BLACK               371
# BLACK WITH WHITE     21
# BLACK/BRINDLE         5
#                    ...
# WHITE/ORANGE          5
# WHITE/RED            14
# WHITE/TAN            50
# WHITE/YELLOW          2
# YELLOW               51
# Length: 72, dtype: int64

# %%
#count unique values- Count (groupby().count())

my_df2.groupby('Color').count()
# Out:
#                   Breed  DogName  OwnerZip
# Color
# APRICOT              15       15        15
# BEIGE                 5        5         5
# BLACK               371      371       371
# BLACK WITH WHITE     21       21        21
# BLACK/BRINDLE         5        5         5
# ...                 ...      ...       ...
# WHITE/ORANGE          5        5         5
# WHITE/RED            14       14        14
# WHITE/TAN            50       50        50
# WHITE/YELLOW          2        2         2
# YELLOW               51       51        51
#
# [72 rows x 3 columns]

# %%
#
my_df2.apply(pd.value_counts)
# Out:
#         Breed  Color  DogName  OwnerZip
# 15003     NaN    NaN      NaN       4.0
# 15005     NaN    NaN      NaN       5.0
# 15006     NaN    NaN      NaN       1.0
# 15007     NaN    NaN      NaN       2.0
# 15014     NaN    NaN      NaN       2.0
# ...       ...    ...      ...       ...
# ZORRO     NaN    NaN      1.0       NaN
# ZURI      NaN    NaN      1.0       NaN
# ZUZU      NaN    NaN      2.0       NaN
# stella    NaN    NaN      1.0       NaN
# suzie     NaN    NaN      1.0       NaN
#
# [1783 rows x 4 columns]

# %%
my_df=pd.read_csv('dog_data_short.csv')
my_df
# Out:
#                  Breed        Color  DogName  OwnerZip
# 0             COCKAPOO        BROWN  CHARLEY     15236
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238
# 2        BELG MALINOIS      BRINDLE     EICH     15238
# 3                MIXED  BLACK/BROWN    ARROW     15104
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139

# %%
#add column from list (if dont match the row size with the gender size it will throw an error)
gender=['Male','Female','Male','Male','Female']

my_df['Gender']=gender
my_df
# Out:
#                  Breed        Color  DogName  OwnerZip  Gender
# 0             COCKAPOO        BROWN  CHARLEY     15236    Male
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238  Female
# 2        BELG MALINOIS      BRINDLE     EICH     15238    Male
# 3                MIXED  BLACK/BROWN    ARROW     15104    Male
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139  Female

# %%
# add default values
my_df['Alive']=['yes']*len(my_df)
my_df
# Out:
#                  Breed        Color  DogName  OwnerZip  Gender Alive
# 0             COCKAPOO        BROWN  CHARLEY     15236    Male   yes
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238  Female   yes
# 2        BELG MALINOIS      BRINDLE     EICH     15238    Male   yes
# 3                MIXED  BLACK/BROWN    ARROW     15104    Male   yes
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139  Female   yes

# %%
#add nan value
my_df['Adopted']=[np.nan]*len(my_df)
my_df
# Out:
#                  Breed        Color  DogName  OwnerZip  Gender Alive  Adopted
# 0             COCKAPOO        BROWN  CHARLEY     15236    Male   yes      NaN
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238  Female   yes      NaN
# 2        BELG MALINOIS      BRINDLE     EICH     15238    Male   yes      NaN
# 3                MIXED  BLACK/BROWN    ARROW     15104    Male   yes      NaN
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139  Female   yes      NaN

# %%
# insert() allows position insted of adding in the end (True=allow duplicates)

my_df.insert(1,"Show Dog",['No']*len(my_df),True)
my_df
# Out:
#                  Breed Show Dog        Color  DogName  OwnerZip  Gender Alive  \
# 0             COCKAPOO       No        BROWN  CHARLEY     15236    Male   yes
# 1         GER SHEPHERD       No  BLACK/BROWN   TACODA     15238  Female   yes
# 2        BELG MALINOIS       No      BRINDLE     EICH     15238    Male   yes
# 3                MIXED       No  BLACK/BROWN    ARROW     15104    Male   yes
# 4  AM PIT BULL TERRIER       No  WHITE/BROWN   OAKLEY     15139  Female   yes
#
#    Adopted
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
# assign()- creats new df

new_df=my_df.assign(Horse=['No']*len(my_df))
new_df
# Out:
#                  Breed Show Dog        Color  DogName  OwnerZip  Gender Alive  \
# 0             COCKAPOO       No        BROWN  CHARLEY     15236    Male   yes
# 1         GER SHEPHERD       No  BLACK/BROWN   TACODA     15238  Female   yes
# 2        BELG MALINOIS       No      BRINDLE     EICH     15238    Male   yes
# 3                MIXED       No  BLACK/BROWN    ARROW     15104    Male   yes
# 4  AM PIT BULL TERRIER       No  WHITE/BROWN   OAKLEY     15139  Female   yes
#
#    Adopted Horse
# 0      NaN    No
# 1      NaN    No
# 2      NaN    No
# 3      NaN    No
# 4      NaN    No

# %%
my_df
# Out:
#                  Breed Show Dog        Color  DogName  OwnerZip  Gender Alive  \
# 0             COCKAPOO       No        BROWN  CHARLEY     15236    Male   yes
# 1         GER SHEPHERD       No  BLACK/BROWN   TACODA     15238  Female   yes
# 2        BELG MALINOIS       No      BRINDLE     EICH     15238    Male   yes
# 3                MIXED       No  BLACK/BROWN    ARROW     15104    Male   yes
# 4  AM PIT BULL TERRIER       No  WHITE/BROWN   OAKLEY     15139  Female   yes
#
#    Adopted
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
df=pd.read_csv('dog_data_short.csv')
df
# Out:
#                  Breed        Color  DogName  OwnerZip
# 0             COCKAPOO        BROWN  CHARLEY     15236
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238
# 2        BELG MALINOIS      BRINDLE     EICH     15238
# 3                MIXED  BLACK/BROWN    ARROW     15104
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139

# %%
gender=['Male','Female','Male','Male','Female']

df['Gender']=gender
df
# Out:
#                  Breed        Color  DogName  OwnerZip  Gender
# 0             COCKAPOO        BROWN  CHARLEY     15236    Male
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238  Female
# 2        BELG MALINOIS      BRINDLE     EICH     15238    Male
# 3                MIXED  BLACK/BROWN    ARROW     15104    Male
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139  Female

# %%
#remove column (axis- its either row heading or column heading)

# axis=0 for row
#axis=1 for column


df.drop('Gender',axis=1)
# Out:
#                  Breed        Color  DogName  OwnerZip
# 0             COCKAPOO        BROWN  CHARLEY     15236
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238
# 2        BELG MALINOIS      BRINDLE     EICH     15238
# 3                MIXED  BLACK/BROWN    ARROW     15104
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139

# %%
#data is not droped until u confirm
# to confirm put inplase=True 
df
# Out:
#                  Breed        Color  DogName  OwnerZip  Gender
# 0             COCKAPOO        BROWN  CHARLEY     15236    Male
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238  Female
# 2        BELG MALINOIS      BRINDLE     EICH     15238    Male
# 3                MIXED  BLACK/BROWN    ARROW     15104    Male
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139  Female

# %%
df.drop('Gender',axis=1,inplace=True)
df
# Out:
#                  Breed        Color  DogName  OwnerZip
# 0             COCKAPOO        BROWN  CHARLEY     15236
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238
# 2        BELG MALINOIS      BRINDLE     EICH     15238
# 3                MIXED  BLACK/BROWN    ARROW     15104
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139

# %%
df
# Out:
#                  Breed        Color  DogName  OwnerZip
# 0             COCKAPOO        BROWN  CHARLEY     15236
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238
# 2        BELG MALINOIS      BRINDLE     EICH     15238
# 3                MIXED  BLACK/BROWN    ARROW     15104
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139

# %%
# remove row

df.drop(3, axis=0)
# Out:
#                  Breed        Color  DogName  OwnerZip
# 0             COCKAPOO        BROWN  CHARLEY     15236
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238
# 2        BELG MALINOIS      BRINDLE     EICH     15238
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139

# %%
df
# Out:
#                  Breed        Color  DogName  OwnerZip
# 0             COCKAPOO        BROWN  CHARLEY     15236
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238
# 2        BELG MALINOIS      BRINDLE     EICH     15238
# 3                MIXED  BLACK/BROWN    ARROW     15104
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139

# %%
# grab rows by location
df.loc[2]
# Out:
# Breed       BELG MALINOIS
# Color             BRINDLE
# DogName              EICH
# OwnerZip            15238
# Name: 2, dtype: object

# %%
# grab rows by index location
df.iloc[3]
# Out:
# Breed             MIXED
# Color       BLACK/BROWN
# DogName           ARROW
# OwnerZip          15104
# Name: 3, dtype: object

# %%
# grab specific point (row and column)

df.loc[1,"DogName"]
# Out:
# 'TACODA'

# %%
#subset
# df.loc[[row,row],[column,column]]
df.loc[[1,3,4],['DogName','Breed']]
# Out:
#   DogName                Breed
# 1  TACODA         GER SHEPHERD
# 3   ARROW                MIXED
# 4  OAKLEY  AM PIT BULL TERRIER

# %%
#conditional Slections
c_df=pd.read_csv('dog_data.csv')
c_df
# Out:
#                     Breed              Color        DogName  OwnerZip
# 0                COCKAPOO              BROWN        CHARLEY     15236
# 1            GER SHEPHERD        BLACK/BROWN         TACODA     15238
# 2           BELG MALINOIS            BRINDLE           EICH     15238
# 3                   MIXED        BLACK/BROWN          ARROW     15104
# 4     AM PIT BULL TERRIER        WHITE/BROWN         OAKLEY     15139
# ...                   ...                ...            ...       ...
# 2665         GOLDENDOODLE              BROWN        WINSLOW     15044
# 2666    YORKSHIRE TERRIER        BLACK/BROWN  ROCKY KALAKOS     15220
# 2667              LAB MIX  WHITE/BLACK/BROWN          ELLIE     15220
# 2668         GOLDENDOODLE              WHITE       CLARENCE     15143
# 2669    SHETLAND SHEEPDOG              BLACK        GRIFFIN     15136
#
# [2670 rows x 4 columns]

# %%
# conditional slection
#>< = >= <= etc
#returns Booleans
c_df == "BROWN"
# Out:
#       Breed  Color  DogName  OwnerZip
# 0     False   True    False     False
# 1     False  False    False     False
# 2     False  False    False     False
# 3     False  False    False     False
# 4     False  False    False     False
# ...     ...    ...      ...       ...
# 2665  False   True    False     False
# 2666  False  False    False     False
# 2667  False  False    False     False
# 2668  False  False    False     False
# 2669  False  False    False     False
#
# [2670 rows x 4 columns]

# %%
# return data not Boolean
c_df[c_df == "BROWN"]
# Out:
#      Breed  Color DogName  OwnerZip
# 0      NaN  BROWN     NaN       NaN
# 1      NaN    NaN     NaN       NaN
# 2      NaN    NaN     NaN       NaN
# 3      NaN    NaN     NaN       NaN
# 4      NaN    NaN     NaN       NaN
# ...    ...    ...     ...       ...
# 2665   NaN  BROWN     NaN       NaN
# 2666   NaN    NaN     NaN       NaN
# 2667   NaN    NaN     NaN       NaN
# 2668   NaN    NaN     NaN       NaN
# 2669   NaN    NaN     NaN       NaN
#
# [2670 rows x 4 columns]

# %%
# only return the column
c_df[c_df=='BROWN']['Color']
# Out:
# 0       BROWN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#         ...
# 2665    BROWN
# 2666      NaN
# 2667      NaN
# 2668      NaN
# 2669      NaN
# Name: Color, Length: 2670, dtype: object

# %%
# multiple selection
m_df=pd.read_csv('dog_data.csv')
m_df
# Out:
#                     Breed              Color        DogName  OwnerZip
# 0                COCKAPOO              BROWN        CHARLEY     15236
# 1            GER SHEPHERD        BLACK/BROWN         TACODA     15238
# 2           BELG MALINOIS            BRINDLE           EICH     15238
# 3                   MIXED        BLACK/BROWN          ARROW     15104
# 4     AM PIT BULL TERRIER        WHITE/BROWN         OAKLEY     15139
# ...                   ...                ...            ...       ...
# 2665         GOLDENDOODLE              BROWN        WINSLOW     15044
# 2666    YORKSHIRE TERRIER        BLACK/BROWN  ROCKY KALAKOS     15220
# 2667              LAB MIX  WHITE/BLACK/BROWN          ELLIE     15220
# 2668         GOLDENDOODLE              WHITE       CLARENCE     15143
# 2669    SHETLAND SHEEPDOG              BLACK        GRIFFIN     15136
#
# [2670 rows x 4 columns]

# %%
# multiple conditional
m_df[m_df['Color']=='BROWN']
# Out:
#                    Breed  Color           DogName  OwnerZip
# 0               COCKAPOO  BROWN           CHARLEY     15236
# 12      AM PITT BULL MIX  BROWN              KING     15235
# 25            BEAGLE MIX  BROWN  CHRISTINA "TINA"     15025
# 38            BEAGLE MIX  BROWN        HONEY PUCK     15241
# 39             CHIHUAHUA  BROWN              ROXY     15147
# ...                  ...    ...               ...       ...
# 2652  LABRADOR RETRIEVER  BROWN            WESTIN     15237
# 2657        GER SHEPHERD  BROWN             SARAH     15239
# 2660              PUGGLE  BROWN              MACY     15044
# 2663  LABRADOR RETRIEVER  BROWN              NINO     15102
# 2665        GOLDENDOODLE  BROWN           WINSLOW     15044
#
# [309 rows x 4 columns]

# %%
m_df[(m_df['Color']=='BROWN') & (m_df['Breed']=='MIXED')]
# Out:
#       Breed  Color        DogName  OwnerZip
# 42    MIXED  BROWN         STELLA     15044
# 272   MIXED  BROWN           HANK     15220
# 371   MIXED  BROWN          TEDDY     15136
# 402   MIXED  BROWN      GEORGIOUS     15212
# 505   MIXED  BROWN        HERSHEY     15071
# 523   MIXED  BROWN  MINDY MAZUREK     15037
# 572   MIXED  BROWN          STEVE     15229
# 584   MIXED  BROWN           BEAR     15122
# 602   MIXED  BROWN          CHLOE     15106
# 818   MIXED  BROWN         PEANUT     15025
# 943   MIXED  BROWN        DEE DEE     15031
# 946   MIXED  BROWN           SAGE     15035
# 948   MIXED  BROWN          BELLA     15035
# 995   MIXED  BROWN         MISTER     15139
# 1006  MIXED  BROWN        VANESSA     15065
# 1042  MIXED  BROWN           JACK     15223
# 1123  MIXED  BROWN         BUDDIE     15122
# 1195  MIXED  BROWN         COOPER     15071
# 1204  MIXED  BROWN            POE     15044
# 1211  MIXED  BROWN          EPPEY     15218
# ...

# %%
#get length
len(m_df[(m_df['Color']=='BROWN') & (m_df['Breed']=='MIXED')])
# Out:
# 38

# %%
#or |
m_df[(m_df['Color']=='BROWN') | (m_df['Breed']=='MIXED')]
# Out:
#                    Breed        Color           DogName  OwnerZip
# 0               COCKAPOO        BROWN           CHARLEY     15236
# 3                  MIXED  BLACK/BROWN             ARROW     15104
# 12      AM PITT BULL MIX        BROWN              KING     15235
# 15                 MIXED        WHITE             RUSTY     15120
# 25            BEAGLE MIX        BROWN  CHRISTINA "TINA"     15025
# ...                  ...          ...               ...       ...
# 2657        GER SHEPHERD        BROWN             SARAH     15239
# 2658               MIXED        WHITE              LUNA     15017
# 2660              PUGGLE        BROWN              MACY     15044
# 2663  LABRADOR RETRIEVER        BROWN              NINO     15102
# 2665        GOLDENDOODLE        BROWN           WINSLOW     15044
#
# [506 rows x 4 columns]

# %%
# specific with column
m_df[(m_df['Color']=='BROWN') & (m_df['Breed']=='MIXED')]['DogName']
# Out:
# 42             STELLA
# 272              HANK
# 371             TEDDY
# 402         GEORGIOUS
# 505           HERSHEY
# 523     MINDY MAZUREK
# 572             STEVE
# 584              BEAR
# 602             CHLOE
# 818            PEANUT
# 943           DEE DEE
# 946              SAGE
# 948             BELLA
# 995            MISTER
# 1006          VANESSA
# 1042             JACK
# 1123           BUDDIE
# 1195           COOPER
# 1204              POE
# 1211            EPPEY
# 1258             BLUE
# 1322           PHOEBE
# 1466            JAXIE
# 1476            PIPPA
# 1659           ISABEL
# 1780           WILBUR
# 1798             PINO
# 1847           MICKEY
# 2180             KONA
# 2351            BELLA
# 2393           PEANUT
# 2403             TOBY
# 2430             LUCY
# 2441            CASEY
# 2524           PEANUT
# 2562             JEFF
# 2581             BRAX
# 2597           BAILEY
# Name: DogName, dtype: object

# %%
#index
i_df=pd.read_csv('dog_data_short.csv')
i_df
# Out:
#                  Breed        Color  DogName  OwnerZip
# 0             COCKAPOO        BROWN  CHARLEY     15236
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238
# 2        BELG MALINOIS      BRINDLE     EICH     15238
# 3                MIXED  BLACK/BROWN    ARROW     15104
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139

# %%
# create a new column
i_df["Frame Header"]=['D1','D2','D3','D4','D5']
i_df
# Out:
#                  Breed        Color  DogName  OwnerZip Frame Header
# 0             COCKAPOO        BROWN  CHARLEY     15236           D1
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238           D2
# 2        BELG MALINOIS      BRINDLE     EICH     15238           D3
# 3                MIXED  BLACK/BROWN    ARROW     15104           D4
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139           D5

# %%
#set index
i_df.set_index("Frame Header",inplace=True)
i_df
# Out:
#                             Breed        Color  DogName  OwnerZip
# Frame Header
# D1                       COCKAPOO        BROWN  CHARLEY     15236
# D2                   GER SHEPHERD  BLACK/BROWN   TACODA     15238
# D3                  BELG MALINOIS      BRINDLE     EICH     15238
# D4                          MIXED  BLACK/BROWN    ARROW     15104
# D5            AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139

# %%
#reset index
i_df.reset_index(inplace=True)

# %%
i_df
# Out:
#   Frame Header                Breed        Color  DogName  OwnerZip
# 0           D1             COCKAPOO        BROWN  CHARLEY     15236
# 1           D2         GER SHEPHERD  BLACK/BROWN   TACODA     15238
# 2           D3        BELG MALINOIS      BRINDLE     EICH     15238
# 3           D4                MIXED  BLACK/BROWN    ARROW     15104
# 4           D5  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139

# %%
#drop column
i_df.drop("Frame Header",axis=1,inplace=True)

# %%
i_df
# Out:
#                  Breed        Color  DogName  OwnerZip
# 0             COCKAPOO        BROWN  CHARLEY     15236
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238
# 2        BELG MALINOIS      BRINDLE     EICH     15238
# 3                MIXED  BLACK/BROWN    ARROW     15104
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139

# %%
#incomplete data

stuff = {'A':[1,2,3], 'B':[4,np.nan,6], 'C':[7,8,9], 'D':[10,11,12]}
my_df = pd.DataFrame(stuff)
my_df
# Out:
#    A    B  C   D
# 0  1  4.0  7  10
# 1  2  NaN  8  11
# 2  3  6.0  9  12

# %%
#drop rows with null data

my_df.dropna()
# Out:
#    A    B  C   D
# 0  1  4.0  7  10
# 2  3  6.0  9  12

# %%
#drop columns
my_df.dropna(axis=1)
# Out:
#    A  C   D
# 0  1  7  10
# 1  2  8  11
# 2  3  9  12

# %%
my_df
# Out:
#    A    B  C   D
# 0  1  4.0  7  10
# 1  2  NaN  8  11
# 2  3  6.0  9  12

# %%
#more nan value
stuff = {'A':[1,2,3], 'B':[4,np.nan,np.nan], 'C':[7,8,9], 'D':[10,11,12]}
my_df = pd.DataFrame(stuff)
my_df
# Out:
#    A    B  C   D
# 0  1  4.0  7  10
# 1  2  NaN  8  11
# 2  3  NaN  9  12

# %%
my_df.dropna(thresh=2,axis=1)
# Out:
#    A  C   D
# 0  1  7  10
# 1  2  8  11
# 2  3  9  12

# %%
#fill nan

my_df.fillna(value=999)
# Out:
#    A      B  C   D
# 0  1    4.0  7  10
# 1  2  999.0  8  11
# 2  3  999.0  9  12

# %%
my_df.fillna(value=my_df['B'].mean())
# Out:
#    A    B  C   D
# 0  1  4.0  7  10
# 1  2  4.0  8  11
# 2  3  4.0  9  12

# %%
my_df.fillna(value=my_df['B'].min())
# Out:
#    A    B  C   D
# 0  1  4.0  7  10
# 1  2  4.0  8  11
# 2  3  4.0  9  12

# %%
stuff = {
    'Corporation':['Apple', 'Google', 'Meta', 'Apple', 'Google','Meta'],
    'Employees':['John', 'April', 'Wes', 'Beth', 'Justin', 'Steph'],
    'Salary':[200, 220, 190, 130, 120, 150]}
# Create Dataframe
my_df = pd.DataFrame(stuff)
my_df
# Out:
#   Corporation Employees  Salary
# 0       Apple      John     200
# 1      Google     April     220
# 2        Meta       Wes     190
# 3       Apple      Beth     130
# 4      Google    Justin     120
# 5        Meta     Steph     150

# %%
#group by corporation
company=my_df.groupby('Corporation')

# %%
#sum
company.sum()
# Out:
#              Salary
# Corporation
# Apple           330
# Google          340
# Meta            340

# %%
#mean
company.mean()
# Out:
#              Salary
# Corporation
# Apple         165.0
# Google        170.0
# Meta          170.0

# %%
company.max()
# Out:
#             Employees  Salary
# Corporation
# Apple            John     200
# Google         Justin     220
# Meta              Wes     190

# %%
company.std()
# Out:
#                 Salary
# Corporation
# Apple        49.497475
# Google       70.710678
# Meta         28.284271

# %%
company.count()
# Out:
#              Employees  Salary
# Corporation
# Apple                2       2
# Google               2       2
# Meta                 2       2

# %%
company.describe()
# Out:
#             Salary
#              count   mean        std    min    25%    50%    75%    max
# Corporation
# Apple          2.0  165.0  49.497475  130.0  147.5  165.0  182.5  200.0
# Google         2.0  170.0  70.710678  120.0  145.0  170.0  195.0  220.0
# Meta           2.0  170.0  28.284271  150.0  160.0  170.0  180.0  190.0

# %%
my_df
# Out:
#   Corporation Employees  Salary
# 0       Apple      John     200
# 1      Google     April     220
# 2        Meta       Wes     190
# 3       Apple      Beth     130
# 4      Google    Justin     120
# 5        Meta     Steph     150

# %%
# Create Function
def times1000(x):
    return format(x * 1000, ",d")

# %%
my_df['Salary'].apply(times1000)
# Out:
# 0    200,000
# 1    220,000
# 2    190,000
# 3    130,000
# 4    120,000
# 5    150,000
# Name: Salary, dtype: object

# %%
# Make it Into a DataFrame
pd.DataFrame(my_df["Salary"].apply(times1000))
# Out:
#     Salary
# 0  200,000
# 1  220,000
# 2  190,000
# 3  130,000
# 4  120,000
# 5  150,000

# %%
# Add Elder Last Name
def namer(x):
    if x == "John":
        return "John Elder"
    else:
        return "Not Important"

# %%
# Show Elder Last Name
my_df["Employees"].apply(namer)
# Out:
# 0       John Elder
# 1    Not Important
# 2    Not Important
# 3    Not Important
# 4    Not Important
# 5    Not Important
# Name: Employees, dtype: object

# %%
# Use Lambda
pd.DataFrame(my_df["Salary"].apply(lambda x: format(x * 1000, ",d")))
# Out:
#     Salary
# 0  200,000
# 1  220,000
# 2  190,000
# 3  130,000
# 4  120,000
# 5  150,000

# %%
# Function on multiple columns
def namer(x):
    return "Code: " + x

# %%
# Apply To Two Columns
my_df[["Corporation", "Employees"]].apply(namer)
# Out:
#     Corporation     Employees
# 0   Code: Apple    Code: John
# 1  Code: Google   Code: April
# 2    Code: Meta     Code: Wes
# 3   Code: Apple    Code: Beth
# 4  Code: Google  Code: Justin
# 5    Code: Meta   Code: Steph

# %%
import pandas as pd
import numpy as np
# import csv file
my_df = pd.read_csv('dog_data.csv')
my_df
# Out:
#                     Breed              Color        DogName  OwnerZip
# 0                COCKAPOO              BROWN        CHARLEY     15236
# 1            GER SHEPHERD        BLACK/BROWN         TACODA     15238
# 2           BELG MALINOIS            BRINDLE           EICH     15238
# 3                   MIXED        BLACK/BROWN          ARROW     15104
# 4     AM PIT BULL TERRIER        WHITE/BROWN         OAKLEY     15139
# ...                   ...                ...            ...       ...
# 2665         GOLDENDOODLE              BROWN        WINSLOW     15044
# 2666    YORKSHIRE TERRIER        BLACK/BROWN  ROCKY KALAKOS     15220
# 2667              LAB MIX  WHITE/BLACK/BROWN          ELLIE     15220
# 2668         GOLDENDOODLE              WHITE       CLARENCE     15143
# 2669    SHETLAND SHEEPDOG              BLACK        GRIFFIN     15136
#
# [2670 rows x 4 columns]

# %%
my_df['DogName']
# Out:
# 0             CHARLEY
# 1              TACODA
# 2                EICH
# 3               ARROW
# 4              OAKLEY
#             ...
# 2665          WINSLOW
# 2666    ROCKY KALAKOS
# 2667            ELLIE
# 2668         CLARENCE
# 2669          GRIFFIN
# Name: DogName, Length: 2670, dtype: object

# %%
my_df['DogName'].value_counts()
# Out:
# LUCY       35
# BELLA      30
# BAILEY     29
# BUDDY      29
# DAISY      26
#            ..
# CHOOKIE     1
# AMY         1
# DEE DEE     1
# KAYLIE      1
# GRIFFIN     1
# Name: DogName, Length: 1428, dtype: int64

# %%
pd.DataFrame(my_df['DogName'].value_counts()).head(50)
# Out:
#          DogName
# LUCY          35
# BELLA         30
# BAILEY        29
# BUDDY         29
# DAISY         26
# MOLLY         23
# MAX           22
# SADIE         20
# CHARLIE       18
# TOBY          17
# ABBY          16
# DUKE          16
# COOPER        15
# SOPHIE        15
# RILEY         15
# JACK          15
# ROCKY         14
# JAKE          14
# CHLOE         13
# COCO          12
# LOLA          12
# MAGGIE        12
# ROSIE         12
# ELLIE         11
# TUCKER        11
# LEO           10
# GUS           10
# ZOEY          10
# PENNY         10
# IZZY          10
# BANDIT        10
# ZOE           10
# BUSTER        10
# ANGEL         10
# LUNA           9
# SYDNEY         9
# BENTLEY        9
# OSCAR          9
# RUBY           9
# BEAR           9
# HARLEY         9
# PEANUT         9
# HEIDI          9
# ROXIE          9
# ZEUS           9
# HOLLY          8
# GRACIE         8
# HUNTER         8
# TEDDY          8
# JACKSON        8

# %%
#grab uniques
my_df['DogName'].unique()
# Out:
# array(['CHARLEY', 'TACODA', 'EICH', ..., 'ROCKY KALAKOS', 'CLARENCE',
#        'GRIFFIN'], dtype=object)

# %%
pd.DataFrame(my_df['DogName'].unique()).head(50)
# Out:
#                     0
# 0             CHARLEY
# 1              TACODA
# 2                EICH
# 3               ARROW
# 4              OAKLEY
# 5              BAILEY
# 6   MIMI PEARL FOSTER
# 7               LEROI
# 8          ZOE VITSAS
# 9               TAFFY
# 10               DUDE
# 11            CHICKIE
# 12               KING
# 13              EMILY
# 14              ELLIE
# 15              RUSTY
# 16                NaN
# 17             JUILET
# 18              ROMEO
# 19               LOLA
# 20                ABE
# 21             MAGGIE
# 22              BUDDY
# 23           PRINCESS
# 24   CHRISTINA "TINA"
# 25              HOWIE
# 26              HAPPY
# 27              LILLY
# 28             SHADOE
# 29              SABLE
# 30              NAHBI
# 31           VALKYRIE
# 32             DOGGIE
# 33     CURIOUS GEORGE
# 34             WILLIE
# 35           SNOWBALL
# 36         HONEY PUCK
# 37               ROXY
# 38             BUMBLE
# 39          BOJANGLES
# ...

# %%
import pandas as pd
import numpy as np
# Create Data
stuff = {
    'Corporation':['Apple', 'Google', 'Meta', 'Apple', 'Google','Meta'],
    'Employees':['John', 'April', 'Wes', 'Beth', 'Justin', 'Steph'],
    'Salary':[200, 220, 190, 130, 120, 150],
}
# Create Dataframe
my_df = pd.DataFrame(stuff)
my_df
# Out:
#   Corporation Employees  Salary
# 0       Apple      John     200
# 1      Google     April     220
# 2        Meta       Wes     190
# 3       Apple      Beth     130
# 4      Google    Justin     120
# 5        Meta     Steph     150

# %%
# sort lowest to high 
my_df.sort_values('Salary')
# Out:
#   Corporation Employees  Salary
# 4      Google    Justin     120
# 3       Apple      Beth     130
# 5        Meta     Steph     150
# 2        Meta       Wes     190
# 0       Apple      John     200
# 1      Google     April     220

# %%
my_df.sort_values('Salary',ascending=False)
# Out:
#   Corporation Employees  Salary
# 1      Google     April     220
# 0       Apple      John     200
# 2        Meta       Wes     190
# 5        Meta     Steph     150
# 3       Apple      Beth     130
# 4      Google    Justin     120

# %%
my_df
# Out:
#   Corporation Employees  Salary
# 0       Apple      John     200
# 1      Google     April     220
# 2        Meta       Wes     190
# 3       Apple      Beth     130
# 4      Google    Justin     120
# 5        Meta     Steph     150

# %%
my_df.sort_values('Salary',ascending=False,inplace=True)

# %%
my_df
# Out:
#   Corporation Employees  Salary
# 1      Google     April     220
# 0       Apple      John     200
# 2        Meta       Wes     190
# 5        Meta     Steph     150
# 3       Apple      Beth     130
# 4      Google    Justin     120

# %%
#sort strings
my_df.sort_values('Corporation',ascending=False,inplace=True)
my_df
# Out:
#   Corporation Employees  Salary
# 2        Meta       Wes     190
# 5        Meta     Steph     150
# 1      Google     April     220
# 4      Google    Justin     120
# 0       Apple      John     200
# 3       Apple      Beth     130

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

my_df=pd.DataFrame(randn(100,4),columns=['Mon','Tue','Wed',"Thu"])
my_df
# Out:
#          Mon       Tue       Wed       Thu
# 0   1.099139  1.491596  0.244527 -1.121589
# 1  -1.213532 -0.605116  1.107368 -1.488105
# 2   0.317517 -0.134271 -0.287574  1.042736
# 3   0.057927  0.181693 -0.943861 -0.276476
# 4  -2.866176 -1.703251 -0.359162  0.847921
# ..       ...       ...       ...       ...
# 95 -0.978510  0.256421 -1.716772  0.192416
# 96  0.525128 -0.643067 -1.179090  0.558439
# 97 -0.055727 -1.512731 -1.030622 -0.048295
# 98 -1.586469  1.369372 -1.797053  0.927248
# 99 -0.959517 -2.179652 -0.102516 -2.421157
#
# [100 rows x 4 columns]

# %%
#histogram

my_df['Wed'].hist()
# Out:
# <AxesSubplot:>

# %%
my_df['Wed'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
my_df['Wed'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
my_df['Wed'].hist(bins=50,grid=False,legend=True)
# Out:
# <AxesSubplot:>

# %%
#area plot
my_df.plot(kind='area',stacked=False)
# Out:
# <AxesSubplot:>

# %%
my_df['Wed'].plot(kind='area',stacked=False)
# Out:
# <AxesSubplot:>

# %%
my_df.abs().plot(kind='area')
# Out:
# <AxesSubplot:>

# %%
#shading
my_df.abs().plot(kind='area',alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
my_df.abs().plot(kind='area',alpha=0.5,title='Area plot')
# Out:
# <AxesSubplot:title={'center':'Area plot'}>

# %%
my_df.abs().plot(kind='area',alpha=0.5,title='Area plot',legend=False)
# Out:
# <AxesSubplot:title={'center':'Area plot'}>

# %%
my_df['Thu'].abs().plot(kind='area',alpha=0.5,title='Area plot',legend=False)
# Out:
# <AxesSubplot:title={'center':'Area plot'}>

# %%
my_df[['Mon','Wed']].abs().plot(kind='area',alpha=0.5,title='Area plot',legend=False)
# Out:
# <AxesSubplot:title={'center':'Area plot'}>

# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

my_df=pd.DataFrame(randn(25,4),columns=['Mon','Tue','Wed',"Thu"])
my_df
# Out:
#          Mon       Tue       Wed       Thu
# 0   1.114432 -1.663796 -0.037274  0.720257
# 1   2.196634 -0.703117 -0.331939 -0.802408
# 2   0.269290  0.681040  0.460316 -0.110427
# 3  -2.991897  1.006359 -0.183043 -2.817610
# 4   0.493425 -1.357300 -0.649775  1.471551
# 5   0.823974 -0.158773 -0.877594 -2.204988
# 6   0.905113  0.547276 -1.633806  0.283740
# 7  -0.747040 -0.880373  0.548303  0.396802
# 8   1.280862 -0.157554 -1.281882 -0.493514
# 9   0.274222 -0.096509 -1.368398  1.316145
# 10 -0.536426 -0.624170  0.575629 -1.246228
# 11  1.340690  0.739678 -0.722958 -1.081299
# 12  0.472428 -0.911913  0.752453  0.677727
# 13  0.987455 -0.411214 -0.011352  2.050518
# 14  0.203088 -1.219965  1.122026 -0.568074
# 15 -0.492470 -0.992195  0.841506  0.142692
# 16 -0.995018  0.457307 -0.619591 -0.453316
# 17  0.564274 -0.620265  0.280830 -0.562371
# 18 -0.005253  0.784308 -0.475204  0.688138
# 19  1.378137  0.838331 -2.104717  0.832713
# 20 -0.854271  0.372900 -1.275645  1.168794
# ...

# %% [markdown]
# my_df.abs().plot(kind="bar")

# %%
my_df.abs().plot(kind="bar")
# Out:
# <AxesSubplot:>
